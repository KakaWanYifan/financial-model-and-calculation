# %%
from matplotlib import pyplot as plt
import random
from matplotlib import font_manager

font = font_manager.FontProperties(fname="",size=12)

x = range(0,120)
y = [random.randint(10,20) for i in range(120)]
plt.plot(x,y)
x_ticks_label = ['编号 '+ format(i) for i in x]
plt.xticks(x[::10],x_ticks_label[::10],rotation=90,fontproperties=font)
plt.yticks(range(min(y),max(y)))
plt.plot(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\python\python37-32\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\python\python37-32\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\python\python37-32\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
# ...
